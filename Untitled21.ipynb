# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
x=pd.read_csv("https://raw.githubusercontent.com/Premalatha-success/Datasets/main/World%20Happiness%20Report.csv")
x
# Out:
#                       Country  Happiness Rank  Happiness Score   Economy  \
# 0                      Norway               1            7.537  1.616463
# 1                     Denmark               2            7.522  1.482383
# 2                     Iceland               3            7.504  1.480633
# 3                 Switzerland               4            7.494  1.564980
# 4                     Finland               5            7.469  1.443572
# ..                        ...             ...              ...       ...
# 148                    Rwanda             151            3.471  0.368746
# 149                     Syria             152            3.462  0.777153
# 150                  Tanzania             153            3.349  0.511136
# 151                   Burundi             154            2.905  0.091623
# 152  Central African Republic             155            2.693  0.000000
#
#        Family    Health   Freedom  Generosity  Corruption  Dystopia  \
# ...

# %%
# top 8 rows
x.sample(8)
# Out:
#                   Country  Happiness Rank  Happiness Score   Economy  \
# 13          United States              14            6.993  1.546259
# 96                  Nepal              99            4.962  0.479820
# 140                 Benin             143            3.657  0.431085
# 2                 Iceland               3            7.504  1.480633
# 35           Saudi Arabia              37            6.344  1.530624
# 80              Venezuela              82            5.250  1.128431
# 20   United Arab Emirates              21            6.648  1.626343
# 128                 Ghana             131            4.120  0.667225
#
#        Family    Health   Freedom  Generosity  Corruption  Dystopia  \
# 13   1.419921  0.774287  0.505741    0.392579    0.135639  2.218113
# 96   1.179283  0.504131  0.440306    0.394096    0.072976  1.891241
# 140  0.435300  0.209930  0.425963    0.207948    0.060929  1.885631
# 2    1.610574  0.833552  0.627163    0.475540    0.153527  2.322715
# ...

# %%
x.dtypes
# Out:
# Country              object
# Happiness Rank        int64
# Happiness Score     float64
# Economy             float64
# Family              float64
# Health              float64
# Freedom             float64
# Generosity          float64
# Corruption          float64
# Dystopia            float64
# Job Satisfaction    float64
# Region               object
# dtype: object

# %%
x.shape
# Out:
# (153, 12)

# %%
x.columns
# Out:
# Index(['Country', 'Happiness Rank', 'Happiness Score', 'Economy', 'Family',
#        'Health', 'Freedom', 'Generosity', 'Corruption', 'Dystopia',
#        'Job Satisfaction', 'Region'],
#       dtype='object')

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country           153 non-null    object
#  1   Happiness Rank    153 non-null    int64
#  2   Happiness Score   153 non-null    float64
#  3   Economy           153 non-null    float64
#  4   Family            153 non-null    float64
#  5   Health            153 non-null    float64
#  6   Freedom           153 non-null    float64
#  7   Generosity        153 non-null    float64
#  8   Corruption        153 non-null    float64
#  9   Dystopia          153 non-null    float64
#  10  Job Satisfaction  151 non-null    float64
#  11  Region            153 non-null    object
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.5+ KB

# %%
x.isnull().sum()
# Out:
# Country             0
# Happiness Rank      0
# Happiness Score     0
# Economy             0
# Family              0
# Health              0
# Freedom             0
# Generosity          0
# Corruption          0
# Dystopia            0
# Job Satisfaction    2
# Region              0
# dtype: int64

# %%
x.describe()
# Out:
#        Happiness Rank  Happiness Score     Economy      Family      Health  \
# count      153.000000       153.000000  153.000000  153.000000  153.000000
# mean        78.169935         5.349281    0.982433    1.186630    0.550117
# std         45.008741         1.134997    0.421901    0.288441    0.237769
# min          1.000000         2.693000    0.000000    0.000000    0.000000
# 25%         40.000000         4.497000    0.659517    1.041990    0.364509
# 50%         78.000000         5.279000    1.064578    1.251826    0.606042
# 75%        117.000000         6.098000    1.315175    1.416404    0.719217
# max        155.000000         7.537000    1.870766    1.610574    0.949492
#
#           Freedom  Generosity  Corruption    Dystopia  Job Satisfaction
# count  153.000000  153.000000  153.000000  153.000000        151.000000
# mean     0.408489    0.245324    0.123179    1.853072         75.209934
# std      0.150744    0.134395    0.102133    0.499490         12.962365
# ...

# %%
x.describe(include="all")
# Out:
#        Country  Happiness Rank  Happiness Score     Economy      Family  \
# count      153      153.000000       153.000000  153.000000  153.000000
# unique     153             NaN              NaN         NaN         NaN
# top     Norway             NaN              NaN         NaN         NaN
# freq         1             NaN              NaN         NaN         NaN
# mean       NaN       78.169935         5.349281    0.982433    1.186630
# std        NaN       45.008741         1.134997    0.421901    0.288441
# min        NaN        1.000000         2.693000    0.000000    0.000000
# 25%        NaN       40.000000         4.497000    0.659517    1.041990
# 50%        NaN       78.000000         5.279000    1.064578    1.251826
# 75%        NaN      117.000000         6.098000    1.315175    1.416404
# max        NaN      155.000000         7.537000    1.870766    1.610574
#
#             Health     Freedom  Generosity  Corruption    Dystopia  \
# ...

# %%
x.describe(include='all').T
# Out:
#                   count unique     top freq       mean        std       min  \
# Country             153    153  Norway    1        NaN        NaN       NaN
# Happiness Rank    153.0    NaN     NaN  NaN  78.169935  45.008741       1.0
# Happiness Score   153.0    NaN     NaN  NaN   5.349281   1.134997     2.693
# Economy           153.0    NaN     NaN  NaN   0.982433   0.421901       0.0
# Family            153.0    NaN     NaN  NaN    1.18663   0.288441       0.0
# Health            153.0    NaN     NaN  NaN   0.550117   0.237769       0.0
# Freedom           153.0    NaN     NaN  NaN   0.408489   0.150744       0.0
# Generosity        153.0    NaN     NaN  NaN   0.245324   0.134395       0.0
# Corruption        153.0    NaN     NaN  NaN   0.123179   0.102133       0.0
# Dystopia          153.0    NaN     NaN  NaN   1.853072    0.49949  0.377914
# Job Satisfaction  151.0    NaN     NaN  NaN  75.209934  12.962365      44.4
# ...

# %%
# countplot is used with one catogorical attribute
# or with two numerical attributes
sns.countplot(data=x)

# %%
sns.countplot(y="Family",data=x)

# %%
sns.countplot(y="Health",data=x)

# %%
sns.countplot(y="Freedom",data=x)

# %%
sns.countplot(y="Health",hue="Family",data=x)

# %%
sns.countplot(y="Happiness Score",hue="Happiness Rank",data=x)

# %%
x.hist(figsize=(10,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1321747160>,
# ...
#       dtype=object)

# %%
x.hist(figsize=(20,100))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f131fae86d0>,
# ...
#       dtype=object)

# %%
#sns.countplot(y="Happiness Score",hue="Happiness Rank",data=x)
sns.boxplot(x="Family",y="Happiness Rank", data=x)
#boxplot - one should be numerical

# %%
x.columns
# Out:
# Index(['Country', 'Happiness Rank', 'Happiness Score', 'Economy', 'Family',
#        'Health', 'Freedom', 'Generosity', 'Corruption', 'Dystopia',
#        'Job Satisfaction', 'Region'],
#       dtype='object')

# %%
pd.crosstab(x['Freedom'],x['Generosity'])
# Out:
# Generosity  0.000000  0.010165  0.028807  0.032210  0.043785  0.045269  \
# Freedom
# 0.000000           0         0         0         0         0         0
# 0.014996           0         0         0         0         0         0
# 0.030370           0         0         0         0         0         0
# 0.059901           0         0         0         0         0         0
# 0.081539           0         0         0         0         0         0
# ...              ...       ...       ...       ...       ...       ...
# 0.626007           0         0         0         0         0         0
# 0.627163           0         0         0         0         0         0
# 0.633376           0         0         0         0         0         0
# 0.635423           0         0         0         0         0         0
# 0.658249           0         0         0         0         0         0
#
# Generosity  0.046693  0.049693  0.052264  0.054009  ...  0.477699  0.489204  \
# ...

# %%
pd.crosstab(x['Health'],x['Corruption'])
# Out:
# Corruption  0.000000  0.004388  0.008965  0.010091  0.011052  0.011866  \
# Health
# 0.000000           0         0         0         0         0         0
# 0.005565           0         0         0         0         0         0
# 0.018773           0         0         0         0         0         0
# 0.041135           0         0         0         0         0         0
# 0.048642           0         0         0         0         0         0
# ...              ...       ...       ...       ...       ...       ...
# 0.888961           0         0         0         0         0         0
# 0.900214           0         0         0         0         0         0
# 0.913476           0         0         0         0         0         0
# 0.943062           0         0         0         0         0         0
# 0.949492           0         0         0         0         0         0
#
# Corruption  0.015317  0.015869  0.022794  0.023029  ...  0.318834  0.324490  \
# ...

# %%
sns.pairplot(x,diag_kind='kde')

# %%
x.columns
# Out:
# Index(['Country', 'Happiness Rank', 'Happiness Score', 'Economy', 'Family',
#        'Health', 'Freedom', 'Generosity', 'Corruption', 'Dystopia',
#        'Job Satisfaction', 'Region'],
#       dtype='object')

# %%
#corelation between two attributes
corr=x.corr()
corr
# Out:
#                   Happiness Rank  Happiness Score   Economy    Family  \
# Happiness Rank          1.000000        -0.992782 -0.811916 -0.738380
# Happiness Score        -0.992782         1.000000  0.811194  0.753815
# Economy                -0.811916         0.811194  1.000000  0.688701
# Family                 -0.738380         0.753815  0.688701  1.000000
# Health                 -0.779191         0.780496  0.841900  0.612003
# Freedom                -0.558380         0.576027  0.375043  0.425937
# Generosity             -0.138480         0.160010 -0.017310  0.046005
# Corruption             -0.413378         0.435854  0.357817  0.233749
# Dystopia               -0.482534         0.474300  0.018464  0.073697
# Job Satisfaction       -0.814535         0.812873  0.700662  0.623266
#
#                     Health   Freedom  Generosity  Corruption  Dystopia  \
# Happiness Rank   -0.779191 -0.558380   -0.138480   -0.413378 -0.482534
# ...

# %%
#sns.heatmap(corr,annot=True,cmap="YIGnBu")

# %%
sns.co
